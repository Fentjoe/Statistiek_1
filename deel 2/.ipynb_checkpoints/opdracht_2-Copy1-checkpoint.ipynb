# %% [markdown]
# Opgave 2 – Temperatuur (30 pt)
# De temperatuur per dag hangt af van verschillende factoren.
# Toets met α=0,05 of de gemiddelde temperatuur per dag afhangt van de
# windrichting, de hoeveelheid bewolking en/of het zicht.
# - Als je concludeert dat alle groepen gemiddeld genomen even goed scoren,
#     geef dan een 95% betrouwbaarheidsinterval voor dit gemiddelde.
# - Als je concludeert dat niet alle groepen gemiddeld genomen even
#     goed scoren, geef dan aan welke groepen significant beter of juist
#     slechter scoren dan andere groepen.
#
# Houd er rekening mee dat sommige variabelen zó veel categorieën
# hebben dat er niet goed mee gerekend kan worden (omdat sommige
# groepen te klein worden) of dat er niets uit op te maken valt. Het kan dus
# nodig zijn om nieuwe variabelen aan te maken waarin (zinvolle)
# categorieën zijn samengevoegd

# %% [markdown]
# ANOVA?

# %%
# inladen bibliotheken en dataset
import scipy.stats as st
from scipy import stats
from scipy.stats import chi2_contingency 
import statsmodels.api as smapi 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
etmgeg = pd.DataFrame(pd.read_csv('etmgeg2.csv'))

# %%
from statsmodels.formula.api import ols
from statsmodels.graphics.api import interaction_plot, abline_plot
from statsmodels.stats.anova import anova_lm
etmgeg.head()
# Out:
#        Datum  Jaar  Maand  Dag Staatshoofd  WindrVec WindrCat9 WindrCat5  \
# 0  27-4-1901  1901      4   27  Wilhelmina       NaN       NaN       NaN
# 1  30-4-1901  1901      4   30  Wilhelmina       NaN       NaN       NaN
# 2  31-8-1901  1901      8   31  Wilhelmina       NaN       NaN       NaN
# 3  27-4-1902  1902      4   27  Wilhelmina       NaN       NaN       NaN
# 4  30-4-1902  1902      4   30  Wilhelmina       NaN       NaN       NaN
#
#    Windsnelh  WindsnelhGem  ...  ZichtMaxCat85  ZichtMaxCat5  ZichtMaxUur  \
# 0        NaN           NaN  ...            NaN           NaN          NaN
# 1        NaN           NaN  ...            NaN           NaN          NaN
# 2        NaN           NaN  ...            NaN           NaN          NaN
# 3        NaN           NaN  ...            NaN           NaN          NaN
# 4        NaN           NaN  ...            NaN           NaN          NaN
#
#    BewolkingGem  VochtighGem  VochtighMax  VochtighMaxUur  VochtighMin  \
# 0           NaN           78          NaN             NaN          NaN
# 1           NaN           84          NaN             NaN          NaN
# 2           NaN           99          NaN             NaN          NaN
# 3           NaN           43          NaN             NaN          NaN
# 4           NaN           77          NaN             NaN          NaN
#
#    VochtighMinUur  Verdamping
# 0             NaN         NaN
# 1             NaN         NaN
# 2             NaN         NaN
# 3             NaN         NaN
# 4             NaN         NaN
#
# [5 rows x 45 columns]

# %%
sns.displot(etmgeg,x='TempGem',hue='BewolkingGem',kind='hist',multiple='dodge',height=3,aspect=2) 
plt.show()
sns.displot(etmgeg,x='TempGem',hue='WindrCat9',kind='kde',height=3,aspect=2)
plt.show()
sns.boxplot(data=etmgeg,x='TempGem',y='WindrCat9',hue='BewolkingGem')
plt.show()
# Out:
# /tmp/ipykernel_2789311/3378106666.py:3: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.displot(etmgeg,x='TempGem',hue='WindrCat9',kind='kde',height=3,aspect=2)

# %% [markdown]
# If the p-value of an ANOVA is less than .05, then we reject the null hypothesis that each group mean is equal.
#
# In this scenario, we can then perform post-hoc tests to determine exactly which groups differ from each other.

# %%
formula = "TempGem ~ C(WindrCat9)"
lm = ols(formula, etmgeg).fit()
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                TempGem   R-squared:                       0.124
# Model:                            OLS   Adj. R-squared:                  0.104
# Method:                 Least Squares   F-statistic:                     6.213
# Date:                Sat, 08 Jun 2024   Prob (F-statistic):           1.62e-07
# Time:                        17:17:45   Log-Likelihood:                -979.21
# No. Observations:                 360   AIC:                             1976.
# Df Residuals:                     351   BIC:                             2011.
# Df Model:                           8
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# Intercept               9.8035      0.493     19.896      0.000       8.834      10.773
# C(WindrCat9)[T.NO]      1.8380      0.762      2.413      0.016       0.340       3.336
# C(WindrCat9)[T.NW]      1.5531      0.710      2.188      0.029       0.157       2.949
# C(WindrCat9)[T.O]       3.8235      0.785      4.868      0.000       2.279       5.368
# C(WindrCat9)[T.Var]     0.1965      3.753      0.052      0.958      -7.184       7.577
# C(WindrCat9)[T.W]       0.6781      0.725      0.936      0.350      -0.747       2.103
# C(WindrCat9)[T.Z]       2.9147      0.814      3.582      0.000       1.314       4.515
# C(WindrCat9)[T.ZO]      4.4665      0.839      5.323      0.000       2.816       6.117
# C(WindrCat9)[T.ZW]      2.6660      0.691      3.859      0.000       1.307       4.025
# ==============================================================================
# Omnibus:                       52.782   Durbin-Watson:                   2.378
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               14.503
# Skew:                           0.145   Prob(JB):                     0.000709
# Kurtosis:                       2.061   Cond. No.                         20.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
