# %% [markdown]
# Opgave 3 – Verdamping (30 pt)
# Vanaf 1957 wordt ook een variabele Verdamping bijgehouden. Uit de
# beschrijving van deze variabele volgt niet direct een duidelijk beeld waar
# deze variabele vandaan komt.
#  Bepaal een zo statistisch valide mogelijk model waarmee
# Verdamping uitgedrukt kan worden in termen van de andere
# variabelen in de dataset.
#  Onderbouw de validiteit van het model.
#  Onderbouw waarom dit het beste model is.
# Houd er rekening mee dat er veel numerieke variabelen in de dataset
# zitten. Dat betekent bijvoorbeeld dat een heatmap onleesbaar kan worden,
# en dat een pairplot heel lang duurt om te berekenen (echt minuten).
# Let op dat veel variabelen onderling sterk gecorreleerd zijn.

# %% [markdown]
# Regressiemodel

# %%
# De benodigde bibliotheken inladen
import pandas as pd                   # Deze drie heb je eigenlijk altijd wel nodig
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns                  # Hiermee maak je mooiere grafieken, zoals de heatmat en de pairplot
import statsmodels as st             
import statsmodels.api as sm           # Hierin zitten onder meer de QQ-plot en de Influence plot
import statsmodels.formula.api as smf  # Hiermee kun je het lineaire regressiemodel opstellen en schatten
import statsmodels.stats.api as sms    # Hierin zit de Breuch-Pagan toets
from statsmodels.stats.outliers_influence import variance_inflation_factor
from scipy import stats                # De meeste toetsen zitten hierin

# %%
df = pd.read_csv('etmgeg2.csv',sep=',')   #Dataframe inladen
df_filtered = df[df['Jaar'] >= 1957] #De data vanaf 1957 selecteren
df = df_filtered[2:]
df['ZichtMinCat85'][:20]
# Out:
# 170    3000-3100 m
# 171    2000-2100 m
# 172         5-6 km
# 173      100-200 m
# 174         6-7 km
# 175    3000-3100 m
# 176       25-26 km
# 177       10-11 km
# 178    2000-2100 m
# 179         5-6 km
# 180    3000-3100 m
# 181    3000-3100 m
# 182      800-900 m
# 183         5-6 km
# 184       20-21 km
# 185    1500-1600 m
# 186    4000-4100 m
# 187      400-500 m
# 188    2500-2600 m
# 189    3000-3100 m
# Name: ZichtMinCat85, dtype: object

# %%
df.describe()

df.isnull().sum() 

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 201 entries, 170 to 370
# Data columns (total 45 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Datum             201 non-null    object
#  1   Jaar              201 non-null    int64
#  2   Maand             201 non-null    int64
#  3   Dag               201 non-null    int64
#  4   Staatshoofd       201 non-null    object
#  5   WindrVec          201 non-null    float64
#  6   WindrCat9         201 non-null    object
#  7   WindrCat5         201 non-null    object
#  8   Windsnelh         201 non-null    float64
#  9   WindsnelhGem      201 non-null    float64
#  10  WindsnelhMax      201 non-null    float64
#  11  WindsnelhMaxUur   201 non-null    float64
#  12  WindsnelhMin      201 non-null    float64
#  13  WindsnelhMinUur   201 non-null    float64
#  14  Windstoot         201 non-null    float64
#  15  WindstootUur      197 non-null    float64
#  16  TempGem           201 non-null    float64
#  17  TempMin           201 non-null    float64
#  18  TempMinUur        201 non-null    float64
#  19  TempMax           201 non-null    float64
#  20  TempMaxUur        201 non-null    float64
#  21  Zonneschijn       201 non-null    float64
#  22  ZonneschijnPerc   201 non-null    float64
#  23  Straling          201 non-null    float64
#  24  NeerslagDuur      201 non-null    float64
#  25  RegenHoeveelh     201 non-null    float64
#  26  RegenHoeveelhMax  201 non-null    float64
#  27  LuchtdrukGem      201 non-null    float64
#  28  LuchtdrukMax      201 non-null    float64
#  29  LuchtdrukMin      201 non-null    float64
#  30  ZichtMin          201 non-null    float64
#  31  ZichtMinCat85     201 non-null    object
#  32  ZichtMinCat5      201 non-null    object
#  33  ZichtMinUur       201 non-null    float64
#  34  ZichtMax          201 non-null    float64
#  35  ZichtMaxCat85     201 non-null    object
#  36  ZichtMaxCat5      201 non-null    object
#  37  ZichtMaxUur       201 non-null    float64
#  38  BewolkingGem      201 non-null    object
#  39  VochtighGem       201 non-null    int64
#  40  VochtighMax       201 non-null    float64
#  41  VochtighMaxUur    201 non-null    float64
#  42  VochtighMin       201 non-null    float64
#  43  VochtighMinUur    201 non-null    float64
#  44  Verdamping        201 non-null    float64
# dtypes: float64(32), int64(4), object(9)
# memory usage: 72.2+ KB

# %%
# Je kunt allerlei kleuren kiezen bij cmap, met RdYlGn zijn de donkergroene en -rode degene met de sterkste correlatie
plt.figure(figsize=(10, 8))
heat = sns.heatmap(df.corr(numeric_only = True), cmap="RdYlGn", annot=True)
plt.show()

# %%
categ_kolommen = ['WindrCat9', 'WindrCat5', 'ZichtMaxCat85', 'ZichtMaxCat5', 'ZichtMinCat5', 'ZichtMinCat85', 'BewolkingGem'] 
for kolom in categ_kolommen:
    plt.figure(figsize=(10, 6))
    sns.boxplot(x=df['Verdamping'], y=df[kolom])
    plt.title(f'Boxplot of Verdamping by {kolom}')
    plt.xlabel('Verdamping')
    plt.ylabel(kolom)
    plt.show()

# %%
def group_visibility(value):
    # Extract numeric part from the value
    distance = int(value.split('-')[0])
    if distance < 20:
        return '0-20 km'
    elif 20 <= distance < 40:
        return '20-40 km'
    elif 40 <= distance < 60:
        return '40-60 km' 
    elif 4500 <= distance < 4600: 
        return '0-20 km'

df['WindrCat9_NW'] = df['WindrCat9'].map({'NW': 1, 'W': 0, 'NO':0, 'ZO':0, 'O': 0, 'Z': 0, 'N':0, 'ZW':0})  
df['WindrCat9_W'] = df['WindrCat9'].map({'NW': 0, 'W': 1, 'NO':0, 'ZO':0, 'O': 0, 'Z': 0, 'N':0, 'ZW':0}) 
df['WindrCat9_NO'] = df['WindrCat9'].map({'NW': 0, 'W': 0, 'NO':1, 'ZO':0, 'O': 0, 'Z': 0, 'N':0, 'ZW':0})  
df['WindrCat9_ZO'] = df['WindrCat9'].map({'NW': 0, 'W': 0, 'NO':0, 'ZO':1, 'O': 0, 'Z': 0, 'N':0, 'ZW':0})   
df['WindrCat9_O'] = df['WindrCat9'].map({'NW': 0, 'W': 0, 'NO':0, 'ZO':0, 'O': 1, 'Z': 0, 'N':0, 'ZW':0})   
df['WindrCat9_Z'] = df['WindrCat9'].map({'NW': 0, 'W': 0, 'NO':0, 'ZO':0, 'O': 0, 'Z': 1, 'N':0, 'ZW':0})  
df['WindrCat9_N'] = df['WindrCat9'].map({'NW': 0, 'W': 0, 'NO':0, 'ZO':0, 'O': 0, 'Z': 0, 'N':1, 'ZW':0})   
df['WindrCat9_ZW'] = df['WindrCat9'].map({'NW': 0, 'W': 0, 'NO':0, 'ZO':0, 'O': 0, 'Z': 0, 'N':0, 'ZW':1})   
  
df['WindrCat5_W'] = df['WindrCat5'].map({'W': 1, 'O': 0, 'Z': 0, 'N':0}) 
df['WindrCat5_O'] = df['WindrCat5'].map({'W': 0, 'O': 1, 'Z': 0, 'N':0}) 
df['WindrCat5_Z'] = df['WindrCat5'].map({'W': 0, 'O': 0, 'Z': 1, 'N':0})
df['WindrCat5_N'] = df['WindrCat5'].map({'W': 0, 'O': 0, 'Z': 0, 'N':1}) 


# Pas de functie toe op de kolom 'ZichtMaxCat85'
df['ZichtMaxCat85_grouped'] = df['ZichtMaxCat85'].apply(group_visibility)

df['ZichtMaxCat85_0_20'] = df['ZichtMaxCat85_grouped'].map({'0-20 km': 1, '20-40 km': 0, '40-60 km': 0, '4500-4600 m':0}) 
df['ZichtMaxCat85d_20_40'] = df['ZichtMaxCat85_grouped'].map({'0-20 km': 0, '20-40 km': 1, '40-60 km': 0, '4500-4600 m':0}) 
df['ZichtMaxCat85_40_60'] = df['ZichtMaxCat85_grouped'].map({'0-20 km': 0, '20-40 km': 0, '40-60 km': 1, '4500-4600 m':0})   
df['ZichtMaxCat85_4500_4600'] = df['ZichtMaxCat85_grouped'].map({'0-20 km': 0, '20-40 km': 0, '40-60 km': 0, '4500-4600 m':1})  
df   
 
df['ZichtMinCat85_grouped'] = df['ZichtMinCat85'] 

Ends_on_m = df[df['ZichtMinCat85'].str.endswith(' m')]['ZichtMinCat85']  
df.loc[ends_on_m, 'ZichtMinCat85'] = '0-10 km'

# Vervang de waarden zoals gespecificeerd in replacement_dict
replacement_dict = {
    '5-6 km': '0-10 km',
    '6-7 km': '0-10 km',
    '7-8 km': '0-10 km',
    '8-9 km': '0-10 km',
    '9-10 km': '0-10 km',
    '10-11 km': '10-20 km',
    '11-12 km': '10-20 km',
    '12-13 km': '10-20 km',
    '14-15 km': '10-20 km',
    '15-16 km': '10-20 km',
    '17-18 km': '10-20 km',
    '19-20 km': '10-20 km',
    '20-21 km': '20-40 km',
    '25-26 km': '20-40 km',
    '30-35 km': '20-40 km'
}

df['ZichtMinCat85_grouped'] = df['ZichtMinCat85'].replace(replacement_dict)

df['ZichtMinCat85_0_10'] = df['ZichtMinCat85_grouped'].map({'0-10 km': 1, '10-20 km': 0, '20-40 km': 0})  
df['ZichtMinCat85_10_20'] = df['ZichtMinCat85_grouped'].map({'0-10 km': 0, '10-20 km': 1, '20-40 km': 0}) 
df['ZichtMinCat85_20_40'] = df['ZichtMinCat85_grouped'].map({'0-10 km': 0, '10-20 km': 0, '20-40 km': 1})   

klein = []
middel = []

for value in df["BewolkingGem"]:
    if value in ['0/8', '1/8', '2/8', '3/8', '4/8']:
        klein.append(value)
    elif value in ['5/8', '6/8', '7/8', '8/8']:
        middel.append(value)
        
# Wijs de juiste groepen toe aan de DataFrame
df.loc[df['BewolkingGem'].isin(klein), 'BewolkingGem'] = '0-4 /8'
df.loc[df['BewolkingGem'].isin(middel), 'BewolkingGem'] = '5-8 /8' 
 
df['BewolkingGem_kl'] = df['BewolkingGem'].map({'0-4 /8': 1, '5-8 /8': 0})
df['BewolkingGem_gr'] = df['BewolkingGem'].map({'0-4 /8': 0, '5-8 /8': 1}) 

df['ZichtMinCat5_m'] = df['ZichtMinCat5'].map({'matig': 1, 'redelijk': 0, 'slecht': 0, 'goed': 0, 'uitstekend': 0})
df['ZichtMinCat5_r'] = df['ZichtMinCat5'].map({'matig': 0, 'redelijk': 1, 'slecht': 0, 'goed': 0, 'uitstekend': 0})
df['ZichtMinCat5_s'] = df['ZichtMinCat5'].map({'matig': 0, 'redelijk': 0, 'slecht': 1, 'goed': 0, 'uitstekend': 0})
df['ZichtMinCat5_g'] = df['ZichtMinCat5'].map({'matig': 0, 'redelijk': 0, 'slecht': 0, 'goed': 1, 'uitstekend': 0})
df['ZichtMinCat5_u'] = df['ZichtMinCat5'].map({'matig': 0, 'redelijk': 0, 'slecht': 0, 'goed': 0, 'uitstekend': 1})

df['ZichtMaxCat5_m'] = df['ZichtMaxCat5'].map({'matig': 1, 'redelijk': 0, 'goed': 0, 'uitstekend': 0})
df['ZichtMaxCat5_r'] = df['ZichtMaxCat5'].map({'matig': 0, 'redelijk': 1, 'goed': 0, 'uitstekend': 0})
df['ZichtMaxCat5_g'] = df['ZichtMaxCat5'].map({'matig': 0, 'redelijk': 0, 'goed': 1, 'uitstekend': 0})
df['ZichtMaxCat5_u'] = df['ZichtMaxCat5'].map({'matig': 0, 'redelijk': 0, 'goed': 0, 'uitstekend': 1})

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 201 entries, 170 to 370
# Data columns (total 77 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Datum                    201 non-null    object
#  1   Jaar                     201 non-null    int64
#  2   Maand                    201 non-null    int64
#  3   Dag                      201 non-null    int64
#  4   Staatshoofd              201 non-null    object
#  5   WindrVec                 201 non-null    float64
#  6   WindrCat9                201 non-null    object
#  7   WindrCat5                201 non-null    object
#  8   Windsnelh                201 non-null    float64
#  9   WindsnelhGem             201 non-null    float64
#  10  WindsnelhMax             201 non-null    float64
#  11  WindsnelhMaxUur          201 non-null    float64
#  12  WindsnelhMin             201 non-null    float64
#  13  WindsnelhMinUur          201 non-null    float64
#  14  Windstoot                201 non-null    float64
#  15  WindstootUur             197 non-null    float64
#  16  TempGem                  201 non-null    float64
#  17  TempMin                  201 non-null    float64
#  18  TempMinUur               201 non-null    float64
#  19  TempMax                  201 non-null    float64
#  20  TempMaxUur               201 non-null    float64
#  21  Zonneschijn              201 non-null    float64
#  22  ZonneschijnPerc          201 non-null    float64
#  23  Straling                 201 non-null    float64
#  24  NeerslagDuur             201 non-null    float64
#  25  RegenHoeveelh            201 non-null    float64
#  26  RegenHoeveelhMax         201 non-null    float64
#  27  LuchtdrukGem             201 non-null    float64
#  28  LuchtdrukMax             201 non-null    float64
#  29  LuchtdrukMin             201 non-null    float64
#  30  ZichtMin                 201 non-null    float64
#  31  ZichtMinCat85            201 non-null    object
#  32  ZichtMinCat5             201 non-null    object
#  33  ZichtMinUur              201 non-null    float64
#  34  ZichtMax                 201 non-null    float64
#  35  ZichtMaxCat85            201 non-null    object
#  36  ZichtMaxCat5             201 non-null    object
#  37  ZichtMaxUur              201 non-null    float64
#  38  BewolkingGem             201 non-null    object
#  39  VochtighGem              201 non-null    int64
#  40  VochtighMax              201 non-null    float64
#  41  VochtighMaxUur           201 non-null    float64
#  42  VochtighMin              201 non-null    float64
#  43  VochtighMinUur           201 non-null    float64
#  44  Verdamping               201 non-null    float64
#  45  WindrCat9_NW             201 non-null    int64
#  46  WindrCat9_W              201 non-null    int64
#  47  WindrCat9_NO             201 non-null    int64
#  48  WindrCat9_ZO             201 non-null    int64
#  49  WindrCat9_O              201 non-null    int64
#  50  WindrCat9_Z              201 non-null    int64
#  51  WindrCat9_N              201 non-null    int64
#  52  WindrCat9_ZW             201 non-null    int64
#  53  WindrCat5_W              201 non-null    int64
#  54  WindrCat5_O              201 non-null    int64
#  55  WindrCat5_Z              201 non-null    int64
#  56  WindrCat5_N              201 non-null    int64
#  57  ZichtMaxCat85_grouped    201 non-null    object
#  58  ZichtMaxCat85_0_20       201 non-null    int64
#  59  ZichtMaxCat85d_20_40     201 non-null    int64
#  60  ZichtMaxCat85_40_60      201 non-null    int64
#  61  ZichtMaxCat85_4500_4600  201 non-null    int64
#  62  ZichtMinCat85_grouped    201 non-null    object
#  63  ZichtMinCat85_0_10       201 non-null    int64
#  64  ZichtMinCat85_10_20      201 non-null    int64
#  65  ZichtMinCat85_20_40      201 non-null    int64
#  66  BewolkingGem_kl          201 non-null    int64
#  67  BewolkingGem_gr          201 non-null    int64
#  68  ZichtMinCat5_m           201 non-null    int64
#  69  ZichtMinCat5_r           201 non-null    int64
#  70  ZichtMinCat5_s           201 non-null    int64
#  71  ZichtMinCat5_g           201 non-null    int64
#  72  ZichtMinCat5_u           201 non-null    int64
#  73  ZichtMaxCat5_m           201 non-null    int64
#  74  ZichtMaxCat5_r           201 non-null    int64
#  75  ZichtMaxCat5_g           201 non-null    int64
#  76  ZichtMaxCat5_u           201 non-null    int64
# dtypes: float64(32), int64(34), object(11)
# memory usage: 122.5+ KB
# /tmp/ipykernel_2666052/2755511097.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['WindrCat9_NW'] = df['WindrCat9'].map({'NW': 1, 'W': 0, 'NO':0, 'ZO':0, 'O': 0, 'Z': 0, 'N':0, 'ZW':0})
# /tmp/ipykernel_2666052/2755511097.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['WindrCat9_W'] = df['WindrCat9'].map({'NW': 0, 'W': 1, 'NO':0, 'ZO':0, 'O': 0, 'Z': 0, 'N':0, 'ZW':0})
# /tmp/ipykernel_2666052/2755511097.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['WindrCat9_NO'] = df['WindrCat9'].map({'NW': 0, 'W': 0, 'NO':1, 'ZO':0, 'O': 0, 'Z': 0, 'N':0, 'ZW':0})
# /tmp/ipykernel_2666052/2755511097.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['WindrCat9_ZO'] = df['WindrCat9'].map({'NW': 0, 'W': 0, 'NO':0, 'ZO':1, 'O': 0, 'Z': 0, 'N':0, 'ZW':0})
# /tmp/ipykernel_2666052/2755511097.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['WindrCat9_O'] = df['WindrCat9'].map({'NW': 0, 'W': 0, 'NO':0, 'ZO':0, 'O': 1, 'Z': 0, 'N':0, 'ZW':0})
# /tmp/ipykernel_2666052/2755511097.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['WindrCat9_Z'] = df['WindrCat9'].map({'NW': 0, 'W': 0, 'NO':0, 'ZO':0, 'O': 0, 'Z': 1, 'N':0, 'ZW':0})
# /tmp/ipykernel_2666052/2755511097.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['WindrCat9_N'] = df['WindrCat9'].map({'NW': 0, 'W': 0, 'NO':0, 'ZO':0, 'O': 0, 'Z': 0, 'N':1, 'ZW':0})
# /tmp/ipykernel_2666052/2755511097.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['WindrCat9_ZW'] = df['WindrCat9'].map({'NW': 0, 'W': 0, 'NO':0, 'ZO':0, 'O': 0, 'Z': 0, 'N':0, 'ZW':1})
# /tmp/ipykernel_2666052/2755511097.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['WindrCat5_W'] = df['WindrCat5'].map({'W': 1, 'O': 0, 'Z': 0, 'N':0})
# /tmp/ipykernel_2666052/2755511097.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['WindrCat5_O'] = df['WindrCat5'].map({'W': 0, 'O': 1, 'Z': 0, 'N':0})
# /tmp/ipykernel_2666052/2755511097.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['WindrCat5_Z'] = df['WindrCat5'].map({'W': 0, 'O': 0, 'Z': 1, 'N':0})
# /tmp/ipykernel_2666052/2755511097.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['WindrCat5_N'] = df['WindrCat5'].map({'W': 0, 'O': 0, 'Z': 0, 'N':1})
# /tmp/ipykernel_2666052/2755511097.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ZichtMaxCat85_grouped'] = df['ZichtMaxCat85'].apply(group_visibility)
# /tmp/ipykernel_2666052/2755511097.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ZichtMaxCat85_0_20'] = df['ZichtMaxCat85_grouped'].map({'0-20 km': 1, '20-40 km': 0, '40-60 km': 0, '4500-4600 m':0})
# /tmp/ipykernel_2666052/2755511097.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ZichtMaxCat85d_20_40'] = df['ZichtMaxCat85_grouped'].map({'0-20 km': 0, '20-40 km': 1, '40-60 km': 0, '4500-4600 m':0})
# /tmp/ipykernel_2666052/2755511097.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ZichtMaxCat85_40_60'] = df['ZichtMaxCat85_grouped'].map({'0-20 km': 0, '20-40 km': 0, '40-60 km': 1, '4500-4600 m':0})
# /tmp/ipykernel_2666052/2755511097.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ZichtMaxCat85_4500_4600'] = df['ZichtMaxCat85_grouped'].map({'0-20 km': 0, '20-40 km': 0, '40-60 km': 0, '4500-4600 m':1})
# /tmp/ipykernel_2666052/2755511097.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ZichtMinCat85_grouped'] = df['ZichtMinCat85']
# /tmp/ipykernel_2666052/2755511097.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ZichtMinCat85_grouped'] = df['ZichtMinCat85'].replace(replacement_dict)
# /tmp/ipykernel_2666052/2755511097.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ZichtMinCat85_0_10'] = df['ZichtMinCat85_grouped'].map({'0-10 km': 1, '10-20 km': 0, '20-40 km': 0})
# /tmp/ipykernel_2666052/2755511097.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ZichtMinCat85_10_20'] = df['ZichtMinCat85_grouped'].map({'0-10 km': 0, '10-20 km': 1, '20-40 km': 0})
# /tmp/ipykernel_2666052/2755511097.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ZichtMinCat85_20_40'] = df['ZichtMinCat85_grouped'].map({'0-10 km': 0, '10-20 km': 0, '20-40 km': 1})
# /tmp/ipykernel_2666052/2755511097.py:80: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['BewolkingGem_kl'] = df['BewolkingGem'].map({'0-4 /8': 1, '5-8 /8': 0})
# /tmp/ipykernel_2666052/2755511097.py:81: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['BewolkingGem_gr'] = df['BewolkingGem'].map({'0-4 /8': 0, '5-8 /8': 1})
# /tmp/ipykernel_2666052/2755511097.py:83: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ZichtMinCat5_m'] = df['ZichtMinCat5'].map({'matig': 1, 'redelijk': 0, 'slecht': 0, 'goed': 0, 'uitstekend': 0})
# /tmp/ipykernel_2666052/2755511097.py:84: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ZichtMinCat5_r'] = df['ZichtMinCat5'].map({'matig': 0, 'redelijk': 1, 'slecht': 0, 'goed': 0, 'uitstekend': 0})
# /tmp/ipykernel_2666052/2755511097.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ZichtMinCat5_s'] = df['ZichtMinCat5'].map({'matig': 0, 'redelijk': 0, 'slecht': 1, 'goed': 0, 'uitstekend': 0})
# /tmp/ipykernel_2666052/2755511097.py:86: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ZichtMinCat5_g'] = df['ZichtMinCat5'].map({'matig': 0, 'redelijk': 0, 'slecht': 0, 'goed': 1, 'uitstekend': 0})
# /tmp/ipykernel_2666052/2755511097.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ZichtMinCat5_u'] = df['ZichtMinCat5'].map({'matig': 0, 'redelijk': 0, 'slecht': 0, 'goed': 0, 'uitstekend': 1})
# /tmp/ipykernel_2666052/2755511097.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ZichtMaxCat5_m'] = df['ZichtMaxCat5'].map({'matig': 1, 'redelijk': 0, 'goed': 0, 'uitstekend': 0})
# /tmp/ipykernel_2666052/2755511097.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ZichtMaxCat5_r'] = df['ZichtMaxCat5'].map({'matig': 0, 'redelijk': 1, 'goed': 0, 'uitstekend': 0})
# /tmp/ipykernel_2666052/2755511097.py:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ZichtMaxCat5_g'] = df['ZichtMaxCat5'].map({'matig': 0, 'redelijk': 0, 'goed': 1, 'uitstekend': 0})
# /tmp/ipykernel_2666052/2755511097.py:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ZichtMaxCat5_u'] = df['ZichtMaxCat5'].map({'matig': 0, 'redelijk': 0, 'goed': 0, 'uitstekend': 1})

# %%
categ_kolommen = ['WindrCat9', 'WindrCat5', 'ZichtMaxCat85_grouped', 'ZichtMaxCat5', 'ZichtMinCat5', 'ZichtMinCat85_grouped', 'BewolkingGem'] 
for kolom in categ_kolommen:
    plt.figure(figsize=(10, 6))
    sns.boxplot(x=df['Verdamping'], y=df[kolom])
    plt.title(f'Boxplot of Verdamping by {kolom}')
    plt.xlabel('Verdamping')
    plt.ylabel(kolom)
    plt.show()

# %%
sns.scatterplot(y=df.Verdamping, x=df.VochtighGem)  
#Om het verband van de nummerieke variabelen met de verdamping verder te analyseren maken we scatterplots.
# Out:
# <Axes: xlabel='VochtighGem', ylabel='Verdamping'>

# %%
sns.scatterplot(y=df.Verdamping, x=df.VochtighMin)  
#Om het verband van de nummerieke variabelen met de verdamping verder te analyseren maken we scatterplots.
# Out:
# <Axes: xlabel='VochtighMin', ylabel='Verdamping'>

# %%
sns.scatterplot(y=df.Verdamping, x=df.Zonneschijn)  
#Om het verband van de nummerieke variabelen met de verdamping verder te analyseren maken we scatterplots.
# Out:
# <Axes: xlabel='Zonneschijn', ylabel='Verdamping'>

# %%
sns.scatterplot(y=df.Verdamping, x=df.ZonneschijnPerc)  
#Om het verband van de nummerieke variabelen met de verdamping verder te analyseren maken we scatterplots.
# Out:
# <Axes: xlabel='ZonneschijnPerc', ylabel='Verdamping'>

# %%
sns.scatterplot(y=df.Verdamping, x=df.Straling)  
#Om het verband van de nummerieke variabelen met de verdamping verder te analyseren maken we scatterplots.
# Out:
# <Axes: xlabel='Straling', ylabel='Verdamping'>

# %%
sns.scatterplot(y=df.Verdamping, x=df.TempMax)  
#Om het verband van de nummerieke variabelen met de verdamping verder te analyseren maken we scatterplots.
# Out:
# <Axes: xlabel='TempMax', ylabel='Verdamping'>

# %%
sns.scatterplot(y=df.Verdamping, x=df.NeerslagDuur)  
#Om het verband van de nummerieke variabelen met de verdamping verder te analyseren maken we scatterplots.
# Out:
# <Axes: xlabel='NeerslagDuur', ylabel='Verdamping'>

# %%
# We gaan schattingen doen

# We stellen een model op met OLS. 
model = smf.ols('Verdamping~ VochtighGem + Straling + TempMax', data=df)

# Hierbij schatten we het model
regres = model.fit()

# We printen de samenvatting van de regressieresultaten. 
print(regres.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Verdamping   R-squared:                       0.991
# Model:                            OLS   Adj. R-squared:                  0.991
# Method:                 Least Squares   F-statistic:                     7081.
# Date:                Sat, 08 Jun 2024   Prob (F-statistic):          2.67e-200
# Time:                        12:21:11   Log-Likelihood:                 206.19
# No. Observations:                 201   AIC:                            -404.4
# Df Residuals:                     197   BIC:                            -391.2
# Df Model:                           3
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept      -0.3710      0.099     -3.731      0.000      -0.567      -0.175
# VochtighGem    -0.0030      0.001     -3.014      0.003      -0.005      -0.001
# Straling        0.0014   1.82e-05     76.294      0.000       0.001       0.001
# TempMax         0.0485      0.001     34.225      0.000       0.046       0.051
# ==============================================================================
# Omnibus:                        0.420   Durbin-Watson:                   2.030
# Prob(Omnibus):                  0.811   Jarque-Bera (JB):                0.275
# Skew:                          -0.087   Prob(JB):                        0.872
# Kurtosis:                       3.049   Cond. No.                     2.48e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.48e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# Q-Q plotten om de normaliteit te toetsen
sm.qqplot(regres.resid, line='r')
plt.title('Q-Q Plot of Residuals')
plt.show()

# Shapiro-Wilk test om de normaliteit te toetsen
shapiro_test = stats.shapiro(regres.resid)
print("Shapiro-Wilk statistic {:.4f}, p-value: {:.4f}".format(shapiro_test.statistic, shapiro_test.pvalue))
    
# Toets om de centraliteit te toetsen 
t_test = stats.ttest_1samp(regres.resid, 0)
print("t-test statistic for central tendency {:.4f} p-value: {:.4f}".format(t_test.statistic, t_test.pvalue))

# Residuals vs Fitted plotten om de centraliteit te toetsen 
plt.scatter(regres.fittedvalues, regres.resid)
plt.axhline(y=0, color='r', linestyle='--')
plt.title('Residuals vs Fitted Plot')
plt.xlabel('Fitted Values')
plt.ylabel('Residuals')
plt.show()

# Leverage vs Residuals squared plotten om de homoscedasticiteit te toetsen 
influence = regres.get_influence()
leverage = influence.hat_matrix_diag
resid_stud = influence.resid_studentized_internal

plt.scatter(leverage, resid_stud**2, alpha=0.5)
plt.xlabel('Leverage')
plt.ylabel('Standardized Residuals Squared')
plt.title('Residuals Squared vs Leverage Plot')
plt.show()

sm.graphics.influence_plot(regres, size=24, criterion="cooks") 
plt.show()

# Breusch Pagan toets om de homoscedasticiteit te toetsen
brpg = sms.het_breuschpagan(regres.resid, model.exog)
print('Breusch-Pagan statistic: {:.4f}, p-value={:.4f}'.format(brpg[0],brpg[1]))

# Check om multicollineariteit te toetsen
X = pd.DataFrame(model.exog,columns=model.exog_names)
vif = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
print("VIF values:")
for i, col in enumerate(X.columns):
    print(col, ":", vif[i])
# Out:
# Shapiro-Wilk statistic 0.9915, p-value: 0.2866
# t-test statistic for central tendency -0.0000 p-value: 1.0000
# Breusch-Pagan statistic: 0.6271, p-value=0.8902
# VIF values:
# Intercept : 258.9201110579013
# VochtighGem : 2.7804001619802623
# Straling : 2.861751794276372
# TempMax : 1.0636554168784857
