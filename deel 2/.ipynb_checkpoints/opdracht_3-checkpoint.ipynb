# %% [markdown]
# Opgave 3 – Verdamping (30 pt)
# Vanaf 1957 wordt ook een variabele Verdamping bijgehouden. Uit de
# beschrijving van deze variabele volgt niet direct een duidelijk beeld waar
# deze variabele vandaan komt.
#  Bepaal een zo statistisch valide mogelijk model waarmee
# Verdamping uitgedrukt kan worden in termen van de andere
# variabelen in de dataset.
#  Onderbouw de validiteit van het model.
#  Onderbouw waarom dit het beste model is.
# Houd er rekening mee dat er veel numerieke variabelen in de dataset
# zitten. Dat betekent bijvoorbeeld dat een heatmap onleesbaar kan worden,
# en dat een pairplot heel lang duurt om te berekenen (echt minuten).
# Let op dat veel variabelen onderling sterk gecorreleerd zijn.

# %% [markdown]
# Regressiemodel

# %%
# De benodigde bibliotheken inladen
import pandas as pd                   # Deze drie heb je eigenlijk altijd wel nodig
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns                  # Hiermee maak je mooiere grafieken, zoals de heatmat en de pairplot
import statsmodels as st             
import statsmodels.api as sm           # Hierin zitten onder meer de QQ-plot en de Influence plot
import statsmodels.formula.api as smf  # Hiermee kun je het lineaire regressiemodel opstellen en schatten
import statsmodels.stats.api as sms    # Hierin zit de Breuch-Pagan toets
from statsmodels.stats.outliers_influence import variance_inflation_factor
from scipy import stats                # De meeste toetsen zitten hierin

# %%
df = pd.read_csv('etmgeg2.csv',sep=',')  
df = pd.read_csv('etmgeg2.csv',sep=',') 
df_filtered = df[df['Jaar'] >= 1957]
df = df_filtered[2:]
df
# Out:
#          Datum  Jaar  Maand  Dag       Staatshoofd  WindrVec WindrCat9  \
# 170  31-8-1957  1957      8   31           Juliana     295.0        NW
# 171  27-4-1958  1958      4   27           Juliana     278.0         W
# 172  30-4-1958  1958      4   30           Juliana     307.0        NW
# 173  31-8-1958  1958      8   31           Juliana     112.0         O
# 174  27-4-1959  1959      4   27           Juliana     194.0         Z
# ..         ...   ...    ...  ...               ...       ...       ...
# 366  27-4-2023  2023      4   27  Willem-Alexander     117.0        ZO
# 367  30-4-2023  2023      4   30  Willem-Alexander      99.0         O
# 368  31-8-2023  2023      8   31  Willem-Alexander     260.0         W
# 369  27-4-2024  2024      4   27  Willem-Alexander     131.0        ZO
# 370  30-4-2024  2024      4   30  Willem-Alexander     137.0        ZO
#
#     WindrCat5  Windsnelh  WindsnelhGem  ...  ZichtMaxCat85  ZichtMaxCat5  \
# 170         W        2.6           3.6  ...       17-18 km          goed
# 171         W        9.3           9.8  ...       30-35 km    uitstekend
# 172         W        1.0           2.6  ...       15-16 km          goed
# 173         O        1.5           3.6  ...       13-14 km      redelijk
# 174         Z        5.7           6.2  ...       22-23 km          goed
# ..        ...        ...           ...  ...            ...           ...
# 366         O        2.5           2.9  ...       45-50 km    uitstekend
# 367         O        1.7           1.9  ...       45-50 km    uitstekend
# 368         W        2.0           2.7  ...       45-50 km    uitstekend
# 369         O        2.3           2.9  ...       45-50 km    uitstekend
# 370         Z        1.8           2.5  ...       45-50 km    uitstekend
#
#      ZichtMaxUur  BewolkingGem  VochtighGem  VochtighMax  VochtighMaxUur  \
# 170         21.0           7/8           84         97.0             1.0
# 171         11.0           5/8           83         91.0             1.0
# 172         12.0           5/8           79         97.0            24.0
# 173         15.0           6/8           85        100.0             9.0
# 174         15.0           7/8           84         97.0             3.0
# ..           ...           ...          ...          ...             ...
# 366          8.0           7/8           61         98.0             2.0
# 367         14.0           6/8           73         98.0             2.0
# 368         10.0           6/8           78         97.0             6.0
# 369         16.0           8/8           80         93.0             2.0
# 370         13.0           8/8           77         97.0             5.0
#
#      VochtighMin  VochtighMinUur  Verdamping
# 170         69.0            14.0         1.5
# 171         69.0            10.0         1.3
# 172         59.0            12.0         2.4
# 173         57.0            15.0         1.8
# 174         63.0            15.0         1.6
# ..           ...             ...         ...
# 366         39.0            13.0         3.0
# 367         45.0            16.0         3.2
# 368         49.0            13.0         3.1
# 369         61.0            16.0         1.9
# 370         54.0            14.0         3.3
#
# [201 rows x 45 columns]

# %%
df.describe()

df.isnull().sum() 

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 201 entries, 170 to 370
# Data columns (total 45 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Datum             201 non-null    object
#  1   Jaar              201 non-null    int64
#  2   Maand             201 non-null    int64
#  3   Dag               201 non-null    int64
#  4   Staatshoofd       201 non-null    object
#  5   WindrVec          201 non-null    float64
#  6   WindrCat9         201 non-null    object
#  7   WindrCat5         201 non-null    object
#  8   Windsnelh         201 non-null    float64
#  9   WindsnelhGem      201 non-null    float64
#  10  WindsnelhMax      201 non-null    float64
#  11  WindsnelhMaxUur   201 non-null    float64
#  12  WindsnelhMin      201 non-null    float64
#  13  WindsnelhMinUur   201 non-null    float64
#  14  Windstoot         201 non-null    float64
#  15  WindstootUur      197 non-null    float64
#  16  TempGem           201 non-null    float64
#  17  TempMin           201 non-null    float64
#  18  TempMinUur        201 non-null    float64
#  19  TempMax           201 non-null    float64
#  20  TempMaxUur        201 non-null    float64
#  21  Zonneschijn       201 non-null    float64
#  22  ZonneschijnPerc   201 non-null    float64
#  23  Straling          201 non-null    float64
#  24  NeerslagDuur      201 non-null    float64
#  25  RegenHoeveelh     201 non-null    float64
#  26  RegenHoeveelhMax  201 non-null    float64
#  27  LuchtdrukGem      201 non-null    float64
#  28  LuchtdrukMax      201 non-null    float64
#  29  LuchtdrukMin      201 non-null    float64
#  30  ZichtMin          201 non-null    float64
#  31  ZichtMinCat85     201 non-null    object
#  32  ZichtMinCat5      201 non-null    object
#  33  ZichtMinUur       201 non-null    float64
#  34  ZichtMax          201 non-null    float64
#  35  ZichtMaxCat85     201 non-null    object
#  36  ZichtMaxCat5      201 non-null    object
#  37  ZichtMaxUur       201 non-null    float64
#  38  BewolkingGem      201 non-null    object
#  39  VochtighGem       201 non-null    int64
#  40  VochtighMax       201 non-null    float64
#  41  VochtighMaxUur    201 non-null    float64
#  42  VochtighMin       201 non-null    float64
#  43  VochtighMinUur    201 non-null    float64
#  44  Verdamping        201 non-null    float64
# dtypes: float64(32), int64(4), object(9)
# memory usage: 72.2+ KB

# %%
non_numeric_columns = ['Datum', 'Jaar', 'Maand', 'Dag', 'Staatshoofd']
df = df.drop(columns=non_numeric_columns) 
df
# Out:
#      WindrVec WindrCat9 WindrCat5  Windsnelh  WindsnelhGem  WindsnelhMax  \
# 170     295.0        NW         W        2.6           3.6           6.2
# 171     278.0         W         W        9.3           9.8          13.9
# 172     307.0        NW         W        1.0           2.6           3.6
# 173     112.0         O         O        1.5           3.6           6.7
# 174     194.0         Z         Z        5.7           6.2           9.3
# ..        ...       ...       ...        ...           ...           ...
# 366     117.0        ZO         O        2.5           2.9           4.0
# 367      99.0         O         O        1.7           1.9           3.0
# 368     260.0         W         W        2.0           2.7           5.0
# 369     131.0        ZO         O        2.3           2.9           4.0
# 370     137.0        ZO         Z        1.8           2.5           4.0
#
#      WindsnelhMaxUur  WindsnelhMin  WindsnelhMinUur  Windstoot  ...  \
# 170              9.0           0.5             20.0       14.4  ...
# 171             12.0           6.2             24.0       26.8  ...
# 172             17.0           1.5              5.0        6.2  ...
# 173             23.0           1.0              6.0       11.3  ...
# 174              9.0           3.1             20.0       20.1  ...
# ..               ...           ...              ...        ...  ...
# 366              8.0           1.0              1.0        8.0  ...
# 367              8.0           1.0              1.0        6.0  ...
# 368             11.0           0.0             19.0       11.0  ...
# 369             11.0           2.0              1.0        8.0  ...
# 370             10.0           1.0              1.0        7.0  ...
#
#      ZichtMaxCat85  ZichtMaxCat5  ZichtMaxUur  BewolkingGem  VochtighGem  \
# 170       17-18 km          goed         21.0           7/8           84
# 171       30-35 km    uitstekend         11.0           5/8           83
# 172       15-16 km          goed         12.0           5/8           79
# 173       13-14 km      redelijk         15.0           6/8           85
# 174       22-23 km          goed         15.0           7/8           84
# ..             ...           ...          ...           ...          ...
# 366       45-50 km    uitstekend          8.0           7/8           61
# 367       45-50 km    uitstekend         14.0           6/8           73
# 368       45-50 km    uitstekend         10.0           6/8           78
# 369       45-50 km    uitstekend         16.0           8/8           80
# 370       45-50 km    uitstekend         13.0           8/8           77
#
#      VochtighMax  VochtighMaxUur  VochtighMin  VochtighMinUur  Verdamping
# 170         97.0             1.0         69.0            14.0         1.5
# 171         91.0             1.0         69.0            10.0         1.3
# 172         97.0            24.0         59.0            12.0         2.4
# 173        100.0             9.0         57.0            15.0         1.8
# 174         97.0             3.0         63.0            15.0         1.6
# ..           ...             ...          ...             ...         ...
# 366         98.0             2.0         39.0            13.0         3.0
# 367         98.0             2.0         45.0            16.0         3.2
# 368         97.0             6.0         49.0            13.0         3.1
# 369         93.0             2.0         61.0            16.0         1.9
# 370         97.0             5.0         54.0            14.0         3.3
#
# [201 rows x 40 columns]

# %%
# Je kunt allerlei kleuren kiezen bij cmap, met RdYlGn zijn de donkergroene en -rode degene met de sterkste correlatie
plt.figure(figsize=(10, 8))
heat = sns.heatmap(df.corr(numeric_only = True), cmap="RdYlGn", annot=True)
plt.show()

# %%
categ_kolommen = ['WindrCat9', 'WindrCat5', 'ZichtMaxCat85', 'ZichtMaxCat5', 'ZichtMinCat5', 'ZichtMinCat85', 'BewolkingGem'] 
for kolom in categ_kolommen:
    plt.figure(figsize=(10, 6))
    sns.boxplot(x=df['Verdamping'], y=df[kolom])
    plt.title(f'Boxplot of Verdamping by {kolom}')
    plt.xlabel('Verdamping')
    plt.ylabel(column)
    plt.show()

# %%
df['WindrCat9_NW'] = df['WindrCat9'].map({'NW': 1, 'W': 0, 'O': 0, 'Z': 0})
# Out:
#      WindrVec WindrCat9  Windsnelh  WindsnelhGem  WindsnelhMax  \
# 170     295.0        NW        2.6           3.6           6.2
# 171     278.0         W        9.3           9.8          13.9
# 172     307.0        NW        1.0           2.6           3.6
# 173     112.0         O        1.5           3.6           6.7
# 174     194.0         Z        5.7           6.2           9.3
# ..        ...       ...        ...           ...           ...
# 366     117.0        ZO        2.5           2.9           4.0
# 367      99.0         O        1.7           1.9           3.0
# 368     260.0         W        2.0           2.7           5.0
# 369     131.0        ZO        2.3           2.9           4.0
# 370     137.0        ZO        1.8           2.5           4.0
#
#      WindsnelhMaxUur  WindsnelhMin  WindsnelhMinUur  Windstoot  WindstootUur  \
# 170              9.0           0.5             20.0       14.4          11.0
# 171             12.0           6.2             24.0       26.8          13.0
# 172             17.0           1.5              5.0        6.2          19.0
# 173             23.0           1.0              6.0       11.3          23.0
# 174              9.0           3.1             20.0       20.1          13.0
# ..               ...           ...              ...        ...           ...
# 366              8.0           1.0              1.0        8.0          15.0
# 367              8.0           1.0              1.0        6.0          11.0
# 368             11.0           0.0             19.0       11.0          11.0
# 369             11.0           2.0              1.0        8.0          22.0
# 370             10.0           1.0              1.0        7.0          10.0
#
#      ...  ZichtMinCat85_<100 m  BewolkingGem_0/8  BewolkingGem_1/8  \
# 170  ...                 False             False             False
# 171  ...                 False             False             False
# 172  ...                 False             False             False
# 173  ...                 False             False             False
# 174  ...                 False             False             False
# ..   ...                   ...               ...               ...
# 366  ...                 False             False             False
# 367  ...                 False             False             False
# 368  ...                 False             False             False
# 369  ...                 False             False             False
# 370  ...                 False             False             False
#
#      BewolkingGem_2/8  BewolkingGem_3/8  BewolkingGem_4/8  BewolkingGem_5/8  \
# 170             False             False             False             False
# 171             False             False             False              True
# 172             False             False             False              True
# 173             False             False             False             False
# 174             False             False             False             False
# ..                ...               ...               ...               ...
# 366             False             False             False             False
# 367             False             False             False             False
# 368             False             False             False             False
# 369             False             False             False             False
# 370             False             False             False             False
#
#      BewolkingGem_6/8  BewolkingGem_7/8  BewolkingGem_8/8
# 170             False              True             False
# 171             False             False             False
# 172             False             False             False
# 173              True             False             False
# 174             False              True             False
# ..                ...               ...               ...
# 366             False              True             False
# 367              True             False             False
# 368              True             False             False
# 369             False             False              True
# 370             False             False              True
#
# [201 rows x 131 columns]
