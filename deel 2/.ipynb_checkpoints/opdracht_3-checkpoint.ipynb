# %% [markdown]
# Opgave 3 – Verdamping (30 pt)
# Vanaf 1957 wordt ook een variabele Verdamping bijgehouden. Uit de
# beschrijving van deze variabele volgt niet direct een duidelijk beeld waar
# deze variabele vandaan komt.
#  Bepaal een zo statistisch valide mogelijk model waarmee
# Verdamping uitgedrukt kan worden in termen van de andere
# variabelen in de dataset.
#  Onderbouw de validiteit van het model.
#  Onderbouw waarom dit het beste model is.
# Houd er rekening mee dat er veel numerieke variabelen in de dataset
# zitten. Dat betekent bijvoorbeeld dat een heatmap onleesbaar kan worden,
# en dat een pairplot heel lang duurt om te berekenen (echt minuten).
# Let op dat veel variabelen onderling sterk gecorreleerd zijn.

# %% [markdown]
# Regressiemodel

# %%
# De benodigde bibliotheken inladen
import pandas as pd                   # Deze drie heb je eigenlijk altijd wel nodig
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns                  # Hiermee maak je mooiere grafieken, zoals de heatmat en de pairplot
import statsmodels as st             
import statsmodels.api as sm           # Hierin zitten onder meer de QQ-plot en de Influence plot
import statsmodels.formula.api as smf  # Hiermee kun je het lineaire regressiemodel opstellen en schatten
import statsmodels.stats.api as sms    # Hierin zit de Breuch-Pagan toets
from statsmodels.stats.outliers_influence import variance_inflation_factor
from scipy import stats                # De meeste toetsen zitten hierin

# %%
df = pd.read_csv('etmgeg2.csv',sep=',')   #Dataframe inladen
df_filtered = df[df['Jaar'] >= 1957] #De data vanaf 1957 selecteren
df = df_filtered[2:]
df['ZichtMinCat85'][:20]
# Out:
# 170    3000-3100 m
# 171    2000-2100 m
# 172         5-6 km
# 173      100-200 m
# 174         6-7 km
# 175    3000-3100 m
# 176       25-26 km
# 177       10-11 km
# 178    2000-2100 m
# 179         5-6 km
# 180    3000-3100 m
# 181    3000-3100 m
# 182      800-900 m
# 183         5-6 km
# 184       20-21 km
# 185    1500-1600 m
# 186    4000-4100 m
# 187      400-500 m
# 188    2500-2600 m
# 189    3000-3100 m
# Name: ZichtMinCat85, dtype: object

# %%
df.describe()

df.isnull().sum() 

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 201 entries, 170 to 370
# Data columns (total 45 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Datum             201 non-null    object
#  1   Jaar              201 non-null    int64
#  2   Maand             201 non-null    int64
#  3   Dag               201 non-null    int64
#  4   Staatshoofd       201 non-null    object
#  5   WindrVec          201 non-null    float64
#  6   WindrCat9         201 non-null    object
#  7   WindrCat5         201 non-null    object
#  8   Windsnelh         201 non-null    float64
#  9   WindsnelhGem      201 non-null    float64
#  10  WindsnelhMax      201 non-null    float64
#  11  WindsnelhMaxUur   201 non-null    float64
#  12  WindsnelhMin      201 non-null    float64
#  13  WindsnelhMinUur   201 non-null    float64
#  14  Windstoot         201 non-null    float64
#  15  WindstootUur      197 non-null    float64
#  16  TempGem           201 non-null    float64
#  17  TempMin           201 non-null    float64
#  18  TempMinUur        201 non-null    float64
#  19  TempMax           201 non-null    float64
#  20  TempMaxUur        201 non-null    float64
#  21  Zonneschijn       201 non-null    float64
#  22  ZonneschijnPerc   201 non-null    float64
#  23  Straling          201 non-null    float64
#  24  NeerslagDuur      201 non-null    float64
#  25  RegenHoeveelh     201 non-null    float64
#  26  RegenHoeveelhMax  201 non-null    float64
#  27  LuchtdrukGem      201 non-null    float64
#  28  LuchtdrukMax      201 non-null    float64
#  29  LuchtdrukMin      201 non-null    float64
#  30  ZichtMin          201 non-null    float64
#  31  ZichtMinCat85     201 non-null    object
#  32  ZichtMinCat5      201 non-null    object
#  33  ZichtMinUur       201 non-null    float64
#  34  ZichtMax          201 non-null    float64
#  35  ZichtMaxCat85     201 non-null    object
#  36  ZichtMaxCat5      201 non-null    object
#  37  ZichtMaxUur       201 non-null    float64
#  38  BewolkingGem      201 non-null    object
#  39  VochtighGem       201 non-null    int64
#  40  VochtighMax       201 non-null    float64
#  41  VochtighMaxUur    201 non-null    float64
#  42  VochtighMin       201 non-null    float64
#  43  VochtighMinUur    201 non-null    float64
#  44  Verdamping        201 non-null    float64
# dtypes: float64(32), int64(4), object(9)
# memory usage: 72.2+ KB

# %%
# Je kunt allerlei kleuren kiezen bij cmap, met RdYlGn zijn de donkergroene en -rode degene met de sterkste correlatie
plt.figure(figsize=(10, 8))
heat = sns.heatmap(df.corr(numeric_only = True), cmap="RdYlGn", annot=True)
plt.show()

# %%
categ_kolommen = ['WindrCat9', 'WindrCat5', 'ZichtMaxCat85', 'ZichtMaxCat5', 'ZichtMinCat5', 'ZichtMinCat85', 'BewolkingGem'] 
for kolom in categ_kolommen:
    plt.figure(figsize=(10, 6))
    sns.boxplot(x=df['Verdamping'], y=df[kolom])
    plt.title(f'Boxplot of Verdamping by {kolom}')
    plt.xlabel('Verdamping')
    plt.ylabel(kolom)
    plt.show()

# %%
def group_visibility(value):
    # Extract numeric part from the value
    distance = int(value.split('-')[0])
    if distance < 20:
        return '0-20 km'
    elif 20 <= distance < 40:
        return '20-40 km'
    elif 40 <= distance < 60:
        return '40-60 km' 
    elif 4500 <= distance < 4600: 
        return '0-20 km'

df['WindrCat9_NW'] = df['WindrCat9'].map({'NW': 1, 'W': 0, 'NO':0, 'ZO':0, 'O': 0, 'Z': 0, 'N':0, 'ZW':0})  
df['WindrCat9_W'] = df['WindrCat9'].map({'NW': 0, 'W': 1, 'NO':0, 'ZO':0, 'O': 0, 'Z': 0, 'N':0, 'ZW':0}) 
df['WindrCat9_NO'] = df['WindrCat9'].map({'NW': 0, 'W': 0, 'NO':1, 'ZO':0, 'O': 0, 'Z': 0, 'N':0, 'ZW':0})  
df['WindrCat9_ZO'] = df['WindrCat9'].map({'NW': 0, 'W': 0, 'NO':0, 'ZO':1, 'O': 0, 'Z': 0, 'N':0, 'ZW':0})   
df['WindrCat9_O'] = df['WindrCat9'].map({'NW': 0, 'W': 0, 'NO':0, 'ZO':0, 'O': 1, 'Z': 0, 'N':0, 'ZW':0})   
df['WindrCat9_Z'] = df['WindrCat9'].map({'NW': 0, 'W': 0, 'NO':0, 'ZO':0, 'O': 0, 'Z': 1, 'N':0, 'ZW':0})  
df['WindrCat9_N'] = df['WindrCat9'].map({'NW': 0, 'W': 0, 'NO':0, 'ZO':0, 'O': 0, 'Z': 0, 'N':1, 'ZW':0})   
df['WindrCat9_ZW'] = df['WindrCat9'].map({'NW': 0, 'W': 0, 'NO':0, 'ZO':0, 'O': 0, 'Z': 0, 'N':0, 'ZW':1})   
  
df['WindrCat5_W'] = df['WindrCat5'].map({'W': 1, 'O': 0, 'Z': 0, 'N':0}) 
df['WindrCat5_O'] = df['WindrCat5'].map({'W': 0, 'O': 1, 'Z': 0, 'N':0}) 
df['WindrCat5_Z'] = df['WindrCat5'].map({'W': 0, 'O': 0, 'Z': 1, 'N':0})
df['WindrCat5_N'] = df['WindrCat5'].map({'W': 0, 'O': 0, 'Z': 0, 'N':1}) 


# Pas de functie toe op de kolom 'ZichtMaxCat85'
df['ZichtMaxCat85_grouped'] = df['ZichtMaxCat85'].apply(group_visibility)

df['ZichtMaxCat85_grouped_0-20'] = df['ZichtMaxCat85_grouped'].map({'0-20 km': 1, '20-40 km': 0, '40-60 km': 0, '4500-4600 m':0}) 
df['ZichtMaxCat85_grouped_20-40'] = df['ZichtMaxCat85_grouped'].map({'0-20 km': 0, '20-40 km': 1, '40-60 km': 0, '4500-4600 m':0}) 
df['ZichtMaxCat85_grouped_40-60'] = df['ZichtMaxCat85_grouped'].map({'0-20 km': 0, '20-40 km': 0, '40-60 km': 1, '4500-4600 m':0})   
df['ZichtMaxCat85_grouped_4500-4600'] = df['ZichtMaxCat85_grouped'].map({'0-20 km': 0, '20-40 km': 0, '40-60 km': 0, '4500-4600 m':1})  
df   
 
df['ZichtMinCat85_grouped'] = df['ZichtMinCat85'] 

Ends_on_m = df[df['ZichtMinCat85'].str.endswith(' m')]['ZichtMinCat85']  
df.loc[ends_on_m, 'ZichtMinCat85'] = '0-10 km'

# Vervang de waarden zoals gespecificeerd in replacement_dict
replacement_dict = {
    '5-6 km': '0-10 km',
    '6-7 km': '0-10 km',
    '7-8 km': '0-10 km',
    '8-9 km': '0-10 km',
    '9-10 km': '0-10 km',
    '10-11 km': '10-20 km',
    '11-12 km': '10-20 km',
    '12-13 km': '10-20 km',
    '14-15 km': '10-20 km',
    '15-16 km': '10-20 km',
    '17-18 km': '10-20 km',
    '19-20 km': '10-20 km',
    '20-21 km': '20-40 km',
    '25-26 km': '20-40 km',
    '30-35 km': '20-40 km'
}

df['ZichtMinCat85_grouped'] = df['ZichtMinCat85'].replace(replacement_dict)

df['ZichtMinCat85_grouped_0-10'] = df['ZichtMinCat85_grouped'].map({'0-10 km': 1, '10-20 km': 0, '20-40 km': 0})  
df['ZichtMinCat85_grouped_10-20'] = df['ZichtMinCat85_grouped'].map({'0-10 km': 0, '10-20 km': 1, '20-40 km': 0}) 
df['ZichtMinCat85_grouped_20-40'] = df['ZichtMinCat85_grouped'].map({'0-10 km': 0, '10-20 km': 0, '20-40 km': 1})   

klein = []
middel = []

for value in df["BewolkingGem"]:
    if value in ['0/8', '1/8', '2/8', '3/8', '4/8']:
        klein.append(value)
    elif value in ['5/8', '6/8', '7/8', '8/8']:
        middel.append(value)
        
# Wijs de juiste groepen toe aan de DataFrame
df.loc[df['BewolkingGem'].isin(klein), 'BewolkingGem'] = '0-4 /8'
df.loc[df['BewolkingGem'].isin(middel), 'BewolkingGem'] = '5-8 /8' 
 
df['BewolkingGem'] = df['BewolkingGem'].map({'0-4 /8': 1, '5-8 /8': 0})
df['BewolkingGem'] = df['BewolkingGem'].map({'0-4 /8': 0, '5-8 /8': 1}) 

df['ZichtMinCat5'] = df['ZichtMinCat5'].map({'matig': 1, 'redelijk': 0, 'slecht': 0, 'goed': 0, 'uitstekend': 0})
df['ZichtMinCat5'] = df['ZichtMinCat5'].map({'matig': 0, 'redelijk': 1, 'slecht': 0, 'goed': 0, 'uitstekend': 0})
df['ZichtMinCat5'] = df['ZichtMinCat5'].map({'matig': 0, 'redelijk': 0, 'slecht': 1, 'goed': 0, 'uitstekend': 0})
df['ZichtMinCat5'] = df['ZichtMinCat5'].map({'matig': 0, 'redelijk': 0, 'slecht': 0, 'goed': 1, 'uitstekend': 0})
df['ZichtMinCat5'] = df['ZichtMinCat5'].map({'matig': 0, 'redelijk': 0, 'slecht': 0, 'goed': 0, 'uitstekend': 1})

df['ZichtMaxCat5'] = df['ZichtMaxCat5'].map({'matig': 1, 'redelijk': 0, 'goed': 0, 'uitstekend': 0})
df['ZichtMaxCat5'] = df['ZichtMaxCat5'].map({'matig': 0, 'redelijk': 1, 'goed': 0, 'uitstekend': 0})
df['ZichtMaxCat5'] = df['ZichtMaxCat5'].map({'matig': 0, 'redelijk': 0, 'goed': 1, 'uitstekend': 0})
df['ZichtMaxCat5'] = df['ZichtMaxCat5'].map({'matig': 0, 'redelijk': 0, 'goed': 0, 'uitstekend': 1}) 

df
# Out:
# /tmp/ipykernel_2666052/161449509.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['WindrCat9_NW'] = df['WindrCat9'].map({'NW': 1, 'W': 0, 'NO':0, 'ZO':0, 'O': 0, 'Z': 0, 'N':0, 'ZW':0})
# /tmp/ipykernel_2666052/161449509.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['WindrCat9_W'] = df['WindrCat9'].map({'NW': 0, 'W': 1, 'NO':0, 'ZO':0, 'O': 0, 'Z': 0, 'N':0, 'ZW':0})
# /tmp/ipykernel_2666052/161449509.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['WindrCat9_NO'] = df['WindrCat9'].map({'NW': 0, 'W': 0, 'NO':1, 'ZO':0, 'O': 0, 'Z': 0, 'N':0, 'ZW':0})
# /tmp/ipykernel_2666052/161449509.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['WindrCat9_ZO'] = df['WindrCat9'].map({'NW': 0, 'W': 0, 'NO':0, 'ZO':1, 'O': 0, 'Z': 0, 'N':0, 'ZW':0})
# /tmp/ipykernel_2666052/161449509.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['WindrCat9_O'] = df['WindrCat9'].map({'NW': 0, 'W': 0, 'NO':0, 'ZO':0, 'O': 1, 'Z': 0, 'N':0, 'ZW':0})
# /tmp/ipykernel_2666052/161449509.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['WindrCat9_Z'] = df['WindrCat9'].map({'NW': 0, 'W': 0, 'NO':0, 'ZO':0, 'O': 0, 'Z': 1, 'N':0, 'ZW':0})
# /tmp/ipykernel_2666052/161449509.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['WindrCat9_N'] = df['WindrCat9'].map({'NW': 0, 'W': 0, 'NO':0, 'ZO':0, 'O': 0, 'Z': 0, 'N':1, 'ZW':0})
# /tmp/ipykernel_2666052/161449509.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['WindrCat9_ZW'] = df['WindrCat9'].map({'NW': 0, 'W': 0, 'NO':0, 'ZO':0, 'O': 0, 'Z': 0, 'N':0, 'ZW':1})
# /tmp/ipykernel_2666052/161449509.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['WindrCat5_W'] = df['WindrCat5'].map({'W': 1, 'O': 0, 'Z': 0, 'N':0})
# /tmp/ipykernel_2666052/161449509.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['WindrCat5_O'] = df['WindrCat5'].map({'W': 0, 'O': 1, 'Z': 0, 'N':0})
# /tmp/ipykernel_2666052/161449509.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['WindrCat5_Z'] = df['WindrCat5'].map({'W': 0, 'O': 0, 'Z': 1, 'N':0})
# /tmp/ipykernel_2666052/161449509.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['WindrCat5_N'] = df['WindrCat5'].map({'W': 0, 'O': 0, 'Z': 0, 'N':1})
# /tmp/ipykernel_2666052/161449509.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ZichtMaxCat85_grouped'] = df['ZichtMaxCat85'].apply(group_visibility)
# /tmp/ipykernel_2666052/161449509.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ZichtMaxCat85_grouped_0-20'] = df['ZichtMaxCat85_grouped'].map({'0-20 km': 1, '20-40 km': 0, '40-60 km': 0, '4500-4600 m':0})
# /tmp/ipykernel_2666052/161449509.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ZichtMaxCat85_grouped_20-40'] = df['ZichtMaxCat85_grouped'].map({'0-20 km': 0, '20-40 km': 1, '40-60 km': 0, '4500-4600 m':0})
# /tmp/ipykernel_2666052/161449509.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ZichtMaxCat85_grouped_40-60'] = df['ZichtMaxCat85_grouped'].map({'0-20 km': 0, '20-40 km': 0, '40-60 km': 1, '4500-4600 m':0})
# /tmp/ipykernel_2666052/161449509.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ZichtMaxCat85_grouped_4500-4600'] = df['ZichtMaxCat85_grouped'].map({'0-20 km': 0, '20-40 km': 0, '40-60 km': 0, '4500-4600 m':1})
# /tmp/ipykernel_2666052/161449509.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ZichtMinCat85_grouped'] = df['ZichtMinCat85']
# /tmp/ipykernel_2666052/161449509.py:61: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ZichtMinCat85_grouped'] = df['ZichtMinCat85'].replace(replacement_dict)
# /tmp/ipykernel_2666052/161449509.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ZichtMinCat85_grouped_0-10'] = df['ZichtMinCat85_grouped'].map({'0-10 km': 1, '10-20 km': 0, '20-40 km': 0})
# /tmp/ipykernel_2666052/161449509.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ZichtMinCat85_grouped_10-20'] = df['ZichtMinCat85_grouped'].map({'0-10 km': 0, '10-20 km': 1, '20-40 km': 0})
# /tmp/ipykernel_2666052/161449509.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ZichtMinCat85_grouped_20-40'] = df['ZichtMinCat85_grouped'].map({'0-10 km': 0, '10-20 km': 0, '20-40 km': 1})
# /tmp/ipykernel_2666052/161449509.py:77: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0-4 /8' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[df['BewolkingGem'].isin(klein), 'BewolkingGem'] = '0-4 /8'
# /tmp/ipykernel_2666052/161449509.py:80: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['BewolkingGem'] = df['BewolkingGem'].map({'0-4 /8': 1, '5-8 /8': 0})
# /tmp/ipykernel_2666052/161449509.py:81: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['BewolkingGem'] = df['BewolkingGem'].map({'0-4 /8': 0, '5-8 /8': 1})
# /tmp/ipykernel_2666052/161449509.py:83: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ZichtMinCat5'] = df['ZichtMinCat5'].map({'matig': 1, 'redelijk': 0, 'slecht': 0, 'goed': 0, 'uitstekend': 0})
# /tmp/ipykernel_2666052/161449509.py:84: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ZichtMinCat5'] = df['ZichtMinCat5'].map({'matig': 0, 'redelijk': 1, 'slecht': 0, 'goed': 0, 'uitstekend': 0})
# /tmp/ipykernel_2666052/161449509.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ZichtMinCat5'] = df['ZichtMinCat5'].map({'matig': 0, 'redelijk': 0, 'slecht': 1, 'goed': 0, 'uitstekend': 0})
# /tmp/ipykernel_2666052/161449509.py:86: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ZichtMinCat5'] = df['ZichtMinCat5'].map({'matig': 0, 'redelijk': 0, 'slecht': 0, 'goed': 1, 'uitstekend': 0})
# /tmp/ipykernel_2666052/161449509.py:87: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ZichtMinCat5'] = df['ZichtMinCat5'].map({'matig': 0, 'redelijk': 0, 'slecht': 0, 'goed': 0, 'uitstekend': 1})
# /tmp/ipykernel_2666052/161449509.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ZichtMaxCat5'] = df['ZichtMaxCat5'].map({'matig': 1, 'redelijk': 0, 'goed': 0, 'uitstekend': 0})
# /tmp/ipykernel_2666052/161449509.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ZichtMaxCat5'] = df['ZichtMaxCat5'].map({'matig': 0, 'redelijk': 1, 'goed': 0, 'uitstekend': 0})
# /tmp/ipykernel_2666052/161449509.py:91: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ZichtMaxCat5'] = df['ZichtMaxCat5'].map({'matig': 0, 'redelijk': 0, 'goed': 1, 'uitstekend': 0})
# /tmp/ipykernel_2666052/161449509.py:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ZichtMaxCat5'] = df['ZichtMaxCat5'].map({'matig': 0, 'redelijk': 0, 'goed': 0, 'uitstekend': 1})
#          Datum  Jaar  Maand  Dag       Staatshoofd  WindrVec WindrCat9  \
# 170  31-8-1957  1957      8   31           Juliana     295.0        NW
# 171  27-4-1958  1958      4   27           Juliana     278.0         W
# 172  30-4-1958  1958      4   30           Juliana     307.0        NW
# 173  31-8-1958  1958      8   31           Juliana     112.0         O
# 174  27-4-1959  1959      4   27           Juliana     194.0         Z
# ..         ...   ...    ...  ...               ...       ...       ...
# 366  27-4-2023  2023      4   27  Willem-Alexander     117.0        ZO
# 367  30-4-2023  2023      4   30  Willem-Alexander      99.0         O
# 368  31-8-2023  2023      8   31  Willem-Alexander     260.0         W
# 369  27-4-2024  2024      4   27  Willem-Alexander     131.0        ZO
# 370  30-4-2024  2024      4   30  Willem-Alexander     137.0        ZO
#
#     WindrCat5  Windsnelh  WindsnelhGem  ...  WindrCat5_N  \
# 170         W        2.6           3.6  ...            0
# 171         W        9.3           9.8  ...            0
# 172         W        1.0           2.6  ...            0
# 173         O        1.5           3.6  ...            0
# 174         Z        5.7           6.2  ...            0
# ..        ...        ...           ...  ...          ...
# 366         O        2.5           2.9  ...            0
# 367         O        1.7           1.9  ...            0
# 368         W        2.0           2.7  ...            0
# 369         O        2.3           2.9  ...            0
# 370         Z        1.8           2.5  ...            0
#
#      ZichtMaxCat85_grouped  ZichtMaxCat85_grouped_0-20  \
# 170                0-20 km                           1
# 171               20-40 km                           0
# 172                0-20 km                           1
# 173                0-20 km                           1
# 174               20-40 km                           0
# ..                     ...                         ...
# 366               40-60 km                           0
# 367               40-60 km                           0
# 368               40-60 km                           0
# 369               40-60 km                           0
# 370               40-60 km                           0
#
#      ZichtMaxCat85_grouped_20-40  ZichtMaxCat85_grouped_40-60  \
# 170                            0                            0
# 171                            1                            0
# 172                            0                            0
# 173                            0                            0
# 174                            1                            0
# ..                           ...                          ...
# 366                            0                            1
# 367                            0                            1
# 368                            0                            1
# 369                            0                            1
# 370                            0                            1
#
#      ZichtMaxCat85_grouped_4500-4600  ZichtMinCat85_grouped  \
# 170                                0                0-10 km
# 171                                0                0-10 km
# 172                                0                0-10 km
# 173                                0                0-10 km
# 174                                0                0-10 km
# ..                               ...                    ...
# 366                                0                0-10 km
# 367                                0                0-10 km
# 368                                0                0-10 km
# 369                                0               10-20 km
# 370                                0               10-20 km
#
#      ZichtMinCat85_grouped_0-10  ZichtMinCat85_grouped_10-20  \
# 170                           1                            0
# 171                           1                            0
# 172                           1                            0
# 173                           1                            0
# 174                           1                            0
# ..                          ...                          ...
# 366                           1                            0
# 367                           1                            0
# 368                           1                            0
# 369                           0                            1
# 370                           0                            1
#
#      ZichtMinCat85_grouped_20-40
# 170                            0
# 171                            0
# 172                            0
# 173                            0
# 174                            0
# ..                           ...
# 366                            0
# 367                            0
# 368                            0
# 369                            0
# 370                            0
#
# [201 rows x 66 columns]

# %%
categ_kolommen = ['WindrCat9', 'WindrCat5', 'ZichtMaxCat85_grouped', 'ZichtMaxCat5', 'ZichtMinCat5', 'ZichtMinCat85', 'BewolkingGem'] 
for kolom in categ_kolommen:
    plt.figure(figsize=(10, 6))
    sns.boxplot(x=df['Verdamping'], y=df[kolom])
    plt.title(f'Boxplot of Verdamping by {kolom}')
    plt.xlabel('Verdamping')
    plt.ylabel(kolom)
    plt.show()

# %%
sns.scatterplot(y=df.Verdamping, x=df.VochtighGem)  
#Om het verband van de nummerieke variabelen met de verdamping verder te analyseren maken we scatterplots.
# Out:
# <Axes: xlabel='VochtighGem', ylabel='Verdamping'>

# %%
sns.scatterplot(y=df.Verdamping, x=df.VochtighMin)  
#Om het verband van de nummerieke variabelen met de verdamping verder te analyseren maken we scatterplots.
# Out:
# <Axes: xlabel='VochtighMin', ylabel='Verdamping'>

# %%
sns.scatterplot(y=df.Verdamping, x=df.Zonneschijn)  
#Om het verband van de nummerieke variabelen met de verdamping verder te analyseren maken we scatterplots.
# Out:
# <Axes: xlabel='Zonneschijn', ylabel='Verdamping'>

# %%
sns.scatterplot(y=df.Verdamping, x=df.ZonneschijnPerc)  
#Om het verband van de nummerieke variabelen met de verdamping verder te analyseren maken we scatterplots.
# Out:
# <Axes: xlabel='ZonneschijnPerc', ylabel='Verdamping'>

# %%
sns.scatterplot(y=df.Verdamping, x=df.Straling)  
#Om het verband van de nummerieke variabelen met de verdamping verder te analyseren maken we scatterplots.
# Out:
# <Axes: xlabel='Straling', ylabel='Verdamping'>

# %%
sns.scatterplot(y=df.Verdamping, x=df.TempMax)  
#Om het verband van de nummerieke variabelen met de verdamping verder te analyseren maken we scatterplots.
# Out:
# <Axes: xlabel='TempMax', ylabel='Verdamping'>

# %%
sns.scatterplot(y=df.Verdamping, x=df.NeerslagDuur)  
#Om het verband van de nummerieke variabelen met de verdamping verder te analyseren maken we scatterplots.
# Out:
# <Axes: xlabel='NeerslagDuur', ylabel='Verdamping'>
